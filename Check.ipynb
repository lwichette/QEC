# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lattice_new = np.loadtxt("big_kernel/lattices/final_lattice_0.txt")

# %%
lattice = np.loadtxt("playground/final_lattice.txt")

# %%
plt.imshow(lattice-lattice_new)
