# %%
import sys
import numpy as np
from matplotlib import pyplot as plt

# %%
data = []
f=open('lattice_256x256_T_1.700000_IT_10000000_0.txt')
for l in f:
    data.append([int(c) for c in l.strip(" \n\r")])

# %%
plt.imshow(data,interpolation = "nearest")
