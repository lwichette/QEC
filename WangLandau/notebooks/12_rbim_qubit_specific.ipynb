# %%
import numpy as np
import matplotlib.pyplot as plt
from post_processing import *

# %%
boundary_type = "periodic"
intervals = 10
iterations = 1000
overlap = 0.25
walkers = 8
alpha = 0.8
beta = 1e-8
exchange = 20

error_mean = 0.1
error_variance = 0.0001
X = 4
Y = 4
error = "I"

filename = f"../results/{boundary_type}/error_mean_{error_mean:.6f}/error_variance_{error_variance:.6f}/X_{X}_Y_{Y}/error_class_{error}/StitchedHistogram_intervals_{intervals}_iterations_{iterations}_overlap_{overlap:.6f}_walkers_{walkers}_alpha_{alpha:.6f}_beta_{beta:.10f}_exchange_offset{exchange}.txt"

data = read_results_file(filename)

# %%
d = data[1]['results']

# %%
for i in range(len(data)):

    d = data[i]['results']

    x = list(map(int, d.keys()))
    y = list(d.values())

    # Sort the x and y values based on x
    x, y = zip(*sorted(zip(x, y)))

    # Sort the x and y values based on x
    x, y = zip(*sorted(zip(x, y)))

    # Plotting the data
    plt.figure(figsize=(10,6))
    plt.plot(x, y, marker='o')

    # Labeling the graph
    plt.title('RBIM Qubit Specific Noise 4x4 Lattice')
    plt.xlabel('Energies')
    plt.ylabel('Log_G Values')
    plt.grid(True)

    # Show the plot
    plt.show()
