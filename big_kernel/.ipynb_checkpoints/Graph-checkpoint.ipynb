# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.chdir('results')

# %%
L_32_low = np.loadtxt('low_temperature/L_32_ns_200_ne_200_ni_100000_nw_100.txt')
L_36_low = np.loadtxt('low_temperature/L_36_ns_200_ne_200_ni_50000_nw_100.txt')

# %%
plt.plot(L_32_low[:,1], L_32_low[:,0], marker = 'o', label = "L=32")
plt.plot(L_36_low[:,1], L_36_low[:,0], marker = 'o', label = "L=36")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()

# %%
os.listdir('low_temperature')
# Out:
# ['L_12_ns_200_ne_200_ni_100000_nw_100.txt']

# %%
L_12_high = np.loadtxt('comparison_old_results/L_12_ns_200_ne_200_ni_1000_nw_100.txt')
L_36_high = np.loadtxt('comparison_old_results/L_36_ns_200_ne_200_ni_5000_nw_100.txt')

# %%
L_12_low = np.loadtxt('low_temperature/L_12_ns_200_ne_200_ni_100000_nw_100.txt')
L_36_low = np.loadtxt('low_temperature/L_36_ns_200_ne_200_ni_100000_nw_100.txt')

# %%
plt.plot(L_12_high[:,1], L_12_high[:,0], marker = 'o', label = "L=12_high", color = '#c1d5ea')
plt.plot(L_12_low[:,1], L_12_low[:,0], marker = 'o', label = "L=12_low", color = '#c6e2ff')

plt.plot(L_36_low[:,1], L_36_low[:,0], marker = 'o', label = "L=36_low", color = '#ff6108')
plt.plot(L_36_high[:,1], L_36_high[:,0], marker = 'o', label = "L=36_high", color = '#d3643c')

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()

# %%
res_dict = {}

# %%
for l in os.listdir():
    res_dict[int(l.split('L_')[1].split('_')[0])] = np.loadtxt(l)

# %%
for l in sorted(res_dict.keys()):
    plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = "L="+str(l))
    
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()

# %%
res_dict.keys()
# Out:
# dict_keys([14, 18, 28, 36, 24, 12])

# %%
sorted(res_dict.keys())
# Out:
# [12, 14, 18, 24, 28, 36]

# %%
plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = "L="+str(l))
    
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()
