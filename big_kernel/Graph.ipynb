# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.listdir()
# Out:
# ['test',
#  'results',
#  'Makefile',
#  'Graph.ipynb',
#  'Checks.ipynb',
#  'linearized_big.cu',
#  '.ipynb_checkpoints',
#  'lattices.cu']

# %%
N_12 = np.loadtxt("results/Nishimori/L_12_ns_200_ne_200_ni_1000_nw_100.txt")

# %%
plt.plot(N_12[:,1], N_12[:,0], marker = 'o', label = "L=12")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()

# %%
os.chdir('..')

# %%
os.chdir('open_boundary/results/comparison_old_results')

# %%
L_12 = np.loadtxt('L_12_ns_200_ne_200_ni_1000_nw_100.txt')
L_14 = np.loadtxt('L_14_ns_200_ne_200_ni_1000_nw_100.txt')
L_18 = np.loadtxt('L_18_ns_200_ne_200_ni_1000_nw_100.txt')
L_24 = np.loadtxt('L_24_ns_200_ne_200_ni_20000_nw_100.txt')
L_28 = np.loadtxt('L_28_ns_200_ne_200_ni_20000_nw_100.txt')
L_36 = np.loadtxt('L_36_ns_200_ne_200_ni_20000_nw_100.txt')

# %%
plt.plot(L_12[:,1], L_12[:,0], marker = 'o', label = "L=12")
plt.plot(L_14[:,1], L_14[:,0], marker = 'o', label = "L=14")
plt.plot(L_18[:,1], L_18[:,0], marker = 'o', label = "L=18")
plt.plot(L_24[:,1], L_24[:,0], marker = 'o', label = "L=24")
#plt.plot(L_28[:,1], L_28[:,0], marker = 'o', label = "L=28")
#plt.plot(L_36[:,1], L_36[:,0], marker = 'o', label = "L=36")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()

# %%
os.chdir('results')

# %%
L_32_low = np.loadtxt('low_temperature/L_32_ns_200_ne_200_ni_100000_nw_100.txt')
L_36_low = np.loadtxt('low_temperature/L_36_ns_200_ne_200_ni_50000_nw_100.txt')

# %%
plt.plot(L_32_low[:,1], L_32_low[:,0], marker = 'o', label = "L=32")
plt.plot(L_36_low[:,1], L_36_low[:,0], marker = 'o', label = "L=36")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()

# %%
os.listdir('low_temperature')
# Out:
# ['L_12_ns_200_ne_200_ni_100000_nw_100.txt']

# %%
L_12_high = np.loadtxt('results/comparison_old_results/L_12_ns_200_ne_200_ni_1000_nw_100.txt')
L_36_high = np.loadtxt('results/comparison_old_results/L_36_ns_200_ne_200_ni_5000_nw_100.txt')

# %%
L_12_low = np.loadtxt('results/low_temperature/L_12_ns_200_ne_200_ni_100000_nw_100.txt')
L_36_low = np.loadtxt('results/low_temperature/L_36_ns_200_ne_200_ni_50000_nw_100.txt')

# %%
plt.plot(L_12_high[:,1], L_12_high[:,0], marker = 'o', label = "L=12_high", color = 'b')
plt.plot(L_12_low[:,1], L_12_low[:,0], marker = 'o', label = "L=12_low", color = '#104E8B')

plt.plot(L_36_low[:,1], L_36_low[:,0], marker = 'o', label = "L=36_low", color = '#ff6108')
plt.plot(L_36_high[:,1], L_36_high[:,0], marker = 'o', label = "L=36_high", color = '#d3643c')

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()

# %%
res_dict = {}

# %%
for l in os.listdir():
    res_dict[int(l.split('L_')[1].split('_')[0])] = np.loadtxt(l)

# %%
for l in sorted(res_dict.keys()):
    plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = "L="+str(l))
    
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()

# %%
space = np.linspace(0.103, 0.115, 15)

# %%
space[1]-space[0]
# Out:
# 0.0008571428571428619

# %%
res_dict.keys()
# Out:
# dict_keys([14, 18, 28, 36, 24, 12])

# %%
sorted(res_dict.keys())
# Out:
# [12, 14, 18, 24, 28, 36]

# %%
plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = "L="+str(l))
    
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.axhline(1, color = 'orange')
plt.legend()
