# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
num_lattices = 3

# %%
for i in range(num_lattices):
    lattice = np.loadtxt(f"bonds/final_bonds_{i}.txt")
    plt.figure()
    plt.imshow(lattice)

# %%
for i in range(num_lattices):
    lattice = np.loadtxt(f"lattice/final_lattice_{i}.txt")
    plt.figure()
    plt.imshow(lattice)

# %%
for i in range(num_lattices):
    lattice = np.loadtxt(f"lattice/final_lattice_{i}.txt")
    plt.figure()
    plt.imshow(lattice)

# %%
lattice = np.loadtxt("big_kernel/final.txt")

# %%
plt.imshow(lattice)
plt.axvline()

# %%
for i in range(3):
    plt.figure()
    run_lattice = lattice[:, i*1000:(i+1)*1000]
    plt.imshow(run_lattice)

# %%
interactions = np.loadtxt("big_kernel/final_bonds.txt")
plt.imshow(interactions)
plt.axvline(12)
plt.axvline(24)

# %%
lattice_orig = np.loadtxt("VScode/final.txt")

# %%
plt.imshow(lattice_orig)
