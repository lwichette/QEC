# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('lattice/')

# %%
for l in os.listdir():

    if l.split('_')[1][0] in ["0", "1"]:
        lattice = np.loadtxt(l)
    
        plt.figure()
        plt.imshow(lattice)
        plt.title(l)

# %%
for l in os.listdir():

    if l.split('_')[1][0] in ["0", "1"]:
        lattice = np.loadtxt(l)
    
        plt.figure()
        plt.imshow(lattice)
        plt.title(l)

# %%
for l in os.listdir():

    if l.split('_')[1][0] in ["0", "1"]:
        lattice = np.loadtxt(l)
    
        plt.figure()
        plt.imshow(lattice)
        plt.title(l)

# %%
os.chdir('..')

# %%
os.chdir('results/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 os.chdir('results/')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/'

# %%
os.listdir()
# Out:
# ['profiling',
#  'comparison_old_results',
#  '512_random_spins',
#  '10.719%',
#  '0.10_check',
#  '0.10917',
#  'all_spins_up_error',
#  'few_samples',
#  'test',
#  'all_spins_up']

# %%
os.chdir('10.719%')

# %%
res_dict = {}

# %%
for l in os.listdir():
    size = int(l.split('_')[1])
    res_dict[size] = np.loadtxt(l)

# %%
res_dict = {k: res_dict[k] for k in sorted(res_dict)}

# %%
plt.figure(figsize=(10,6))

for l in res_dict.keys():
    plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = int(l))

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()

# %%
res_dict[l][11:,1].shape
# Out:
# (11,)

# %%
fig = plt.figure(figsize=(10,6))
for l in res_dict.keys():
    if l=="128":
        pass
    else:
        plt.plot(res_dict[l][:,1], res_dict[l][:,0], marker = 'o', label = "L="+str(l))
    
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()

# %%
L_12 = np.loadtxt('L_12_ns_200_ne_200_ni_1000_nw_100.txt')
L_14 = np.loadtxt('L_14_ns_200_ne_200_ni_1000_nw_100.txt')
L_18 = np.loadtxt('L_18_ns_200_ne_200_ni_1000_nw_100.txt')
L_24 = np.loadtxt('L_24_ns_200_ne_200_ni_20000_nw_100.txt')
L_28 = np.loadtxt('L_28_p_0.060000_ns_200_ne_200_ni_20000_nw_100.txt')
L_36 = np.loadtxt('L_36_p_0.060000_ns_200_ne_200_ni_20000_nw_100.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 L_12 = np.loadtxt('L_12_ns_200_ne_200_ni_1000_nw_100.txt')
#       2 L_14 = np.loadtxt('L_14_ns_200_ne_200_ni_1000_nw_100.txt')
#       3 L_18 = np.loadtxt('L_18_ns_200_ne_200_ni_1000_nw_100.txt')
#
# File ~/envs/og/lib/python3.9/site-packages/numpy/lib/npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339             converters=converters, skiplines=skiprows, usecols=usecols,
#    1340             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1341             max_rows=max_rows, quote=quotechar)
#    1343 return arr
#
# ...

# %%
plt.plot(L_12[:,1], L_12[:,0], marker = 'o', label = "L=12")
plt.plot(L_14[:,1], L_14[:,0], marker = 'o', label = "L=14")
plt.plot(L_18[:,1], L_18[:,0], marker = 'o', label = "L=18")
plt.plot(L_24[:,1], L_24[:,0], marker = 'o', label = "L=24")
plt.plot(L_28[:,1], L_28[:,0], marker = 'o', label = "L=28")
plt.plot(L_36[:,1], L_36[:,0], marker = 'o', label = "L=36")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()
