# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('results')

# %%
os.listdir('Nishimori')
# Out:
# ['L_12_ns_200_ne_200_ni_200000_nw_100.txt',
#  'L_12_ns_200_ne_200_ni_1000_nw_100.txt']

# %%
L_12 = np.loadtxt('Nishimori/L_12_ns_200_ne_200_ni_200000_nw_100.txt')

# %%
plt.plot(L_12[:,1], L_12[:,0], marker = 'o', label = "L=12")

plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
plt.legend()
