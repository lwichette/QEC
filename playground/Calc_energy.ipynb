# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lattice = np.loadtxt("lattice/final_lattice_0.txt")

plt.imshow(lattice, interpolation='none')
plt.show()

# %%
interactions = np.loadtxt("lattice/final_bonds.txt")

plt.imshow(interactions, interpolation='none')
plt.show()

# %%
interactions = interactions.reshape(-1)

# %%
results = np.loadtxt("lattice/psi_L.txt")

# %%
results
# Out:
# array([[0.78647 , 1.8     ],
#        [0.72576 , 1.85    ],
#        [0.683472, 1.9     ],
#        [0.604286, 1.95    ],
#        [0.516172, 2.      ],
#        [0.472634, 2.05    ],
#        [0.406845, 2.1     ],
#        [0.349324, 2.15    ],
#        [0.345728, 2.2     ],
#        [0.298332, 2.25    ],
#        [0.272763, 2.3     ],
#        [0.23966 , 2.35    ],
#        [0.217116, 2.4     ]])

# %%
plt.plot(results[:,1], results[:,0], marker = 'o')
plt.xlabel("Temperature T")
plt.ylabel("$ \\xi $ / L")
# Out:
# Text(0, 0.5, '$ \\xi $ / L')

# %%
results = np.loadtxt("lattice/psi_L.txt")

# %%
results
# Out:
# array([[-2.14748365e+09,  1.80000000e+00],
#        [ 0.00000000e+00,  1.85000000e+00],
#        [ 0.00000000e+00,  1.90000000e+00],
#        [ 0.00000000e+00,  1.95000000e+00],
#        [ 0.00000000e+00,  2.00000000e+00],
#        [ 0.00000000e+00,  2.05000000e+00],
#        [ 0.00000000e+00,  2.10000000e+00],
#        [ 0.00000000e+00,  2.15000000e+00],
#        [ 0.00000000e+00,  2.20000000e+00],
#        [ 0.00000000e+00,  2.25000000e+00],
#        [-2.14748365e+09,  2.30000000e+00],
#        [-2.14748365e+09,  2.35000000e+00],
#        [ 0.00000000e+00,  2.40000000e+00]])
